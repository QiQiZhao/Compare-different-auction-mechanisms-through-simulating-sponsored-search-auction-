# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
Pkey= pd.read_csv('keywordID.csv')
KeywordCount=np.empty((len(Pkey),2),dtype='object')
for i in range(len(KeywordCount)):
    KeywordCount[i][1]=0
for i in range(len(Pkey)):
    KeywordCount[i][0]=Pkey['KeywordID'][i]

del Pkey

# %%
KeywordCount
# Out:
# array([['100090ebe40971fd', 0],
#        ['1001140e40fff9fd', 0],
#        ['10024382a4ae7a07', 0],
#        ...,
#        ['fffdbb80538ef8ed', 0],
#        ['fffef5deb4bb2e96', 0],
#        ['ffff85b5babbe077', 0]], dtype=object)

# %%
Pdata= pd.read_csv('finish8.csv')

# %%
len(KeywordCount)
# Out:
# 75359

# %%
len(Pdata)
# Out:
# 75359

# %%
Pdata
# Out:
#                      id  frequency
# 0      100090ebe40971fd          0
# 1      1001140e40fff9fd          0
# 2      10024382a4ae7a07          0
# 3      1002d06dcd20f283          0
# 4      1003306ca93ebfee          0
# 5      1004a8c8af63bb5b          0
# 6      1005df05ad84f962          0
# 7      10068f9fe94d0f16          0
# 8      1006a4984b65f5e5          0
# 9      1006f25cb0122400          0
# 10     1006fe0534f616c9          0
# 11     100752226da94f8a          0
# 12     1008b6594d0930d8          0
# 13     1009e6d758abbd11          0
# 14     100aad48ff6522b5         25
# 15     100ac8b36e0fd037          0
# 16     100aff8b136d865a          0
# 17     100b1cfbdf08ffdc          0
# 18     100c88088924ed6a          0
# 19     100e059c905ad24e          0
# 20     100e12ed2a2712d7          0
# 21     100e524b01ab76be          0
# 22     100e750337bc5b64          0
# 23     100f40c85629e8ba          0
# 24     1010532ee989f0a0          0
# 25     101172a5bc384e0f          0
# 26     10126155001c2902          0
# 27     1012f9ae41403dc5          0
# 28     1013039a3fc8bdf9          0
# 29     10133c24c5fa8e64          0
# ...                 ...        ...
# 75329  ffe637cf46e97622          0
# 75330  ffe697c08de8eb66          0
# 75331  ffe73a2d5906da4e          0
# 75332  ffe75cc854770bd9          0
# 75333  ffe842eea5eb3966          0
# 75334  ffe864a02a1edcec          0
# 75335  ffe9f284a5ac9fb9          0
# 75336  ffebf8ba3b0c655f          0
# 75337  ffec684137ff8d1c          0
# 75338  ffecb00c35c595c4          0
# 75339  ffeec59b78f1ae01          0
# 75340  ffefdde827096b6e          0
# 75341  fff2085c6fc6da2c          0
# 75342  fff24f8dd6ba854a          0
# 75343  fff259f245db1bbf          0
# 75344  fff2b693d3fca872          0
# 75345  fff3d821ed023c5d          0
# 75346  fff5fcf3a0ac0383          0
# 75347  fff646cdae60b288          0
# 75348  fff7e84a7398843d          0
# 75349  fff8b7ea86254be2          0
# 75350  fffbb53767002c3e          0
# 75351  fffc19a23c8a437f          0
# 75352  fffccba65c73aa71          0
# 75353  fffd77b5d6980f7d          0
# 75354  fffd7fb761012737          0
# 75355  fffd8f9419d02de8          0
# 75356  fffdbb80538ef8ed         92
# 75357  fffef5deb4bb2e96          0
# 75358  ffff85b5babbe077          0
#
# [75359 rows x 2 columns]

# %%
KeywordCount[10][1]
# Out:
# 0

# %%
for i in range(len(KeywordCount)):
    KeywordCount[i][1]+=Pdata['frequency'][i]

# %%
np.savetxt("CountKeyword.csv", KeywordCount ,fmt='%5s',delimiter=",")

# %%
KeywordCount
# Out:
# array([['100090ebe40971fd', 3],
#        ['1001140e40fff9fd', 0],
#        ['10024382a4ae7a07', 1],
#        ...,
#        ['fffdbb80538ef8ed', 1973],
#        ['fffef5deb4bb2e96', 0],
#        ['ffff85b5babbe077', 0]], dtype=object)
