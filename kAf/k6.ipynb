# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from time import process_time

# %%
Pdata= pd.read_csv('K6.csv')

# %%
Pdata
# Out:
#       Unnamed: 0             index     K6
# 0              0  324ac734097de5e4  28353
# 1              1  818c76aa1c8fcfcb  28112
# 2              2  8b9f17e47e6282fc  24637
# 3              3  fc4f04e287746c48  21917
# 4              4  5e4d035e3a82ec8f   9711
# 5              5  2fb9ae05f5dbf8f4   8128
# 6              6  6a82ef5b6ade294f   7946
# 7              7  8a6e919b5292bbeb   6404
# 8              8  2ac01c3be4bef1a8   6247
# 9              9  92628b55d746da91   5169
# 10            10  376b9d520656fcf6   4716
# 11            11  62129a60c2c67093   4452
# 12            12  d777cfa1462b7c50   4100
# 13            13  79021a2e2c836c1a   3734
# 14            14  d5f96f67540b6227   3425
# 15            15  3b2c4ba92d860331   3417
# 16            16  30886045ac687868   3155
# 17            17  7d49570aacd3c2a5   2749
# 18            18  4fe1e24de9b82425   2627
# 19            19  7634c051426a6995   2530
# 20            20  a36ccf9abc1281b3   2509
# 21            21  adac25a2dee56446   2281
# 22            22  18d0fde54d625b72   2260
# 23            23  1be1668b5a9df819   2160
# 24            24  174fc33c6a0afe1c   2128
# 25            25  c3b1a0bcf0178bcb   2040
# 26            26  52c1175b74c3030c   2010
# 27            27  a4630d2f744bb704   1900
# 28            28  be35a4052b70c8bd   1888
# 29            29  43161cfc140f8e45   1877
# ...          ...               ...    ...
# 4856        4856  e2fd4644a14f41a0      1
# 4857        4857  2e6c9dff9045e621      1
# 4858        4858  7c7ffe426c938eae      1
# 4859        4859  e884927b2a123265      1
# 4860        4860  275d90e628e96418      1
# 4861        4861  d967f7bd508aa61e      1
# 4862        4862  340598f4abae0fe9      1
# 4863        4863  fe0d726f511466b0      1
# 4864        4864  7605ce070b51c570      1
# 4865        4865  a6e3c456f2ccc027      1
# 4866        4866  4c5c391bebba6bb2      1
# 4867        4867  2afa5e1e39fdd32e      1
# 4868        4868  51291ada4d108bbb      1
# 4869        4869  df0d4ccadd476388      1
# 4870        4870  6a15cc0fa5c41c2f      1
# 4871        4871  85138451d014ed13      1
# 4872        4872  6e3906646c70aa57      1
# 4873        4873  d3f8fbf0b0fe38bf      1
# 4874        4874  ae5eb348765fe4cc      1
# 4875        4875  f06b8c727b5b8804      1
# 4876        4876  8e7aa6320ee56203      1
# 4877        4877  73b12052fef696dd      1
# 4878        4878  1effce3d5601be46      1
# 4879        4879  2f04ab66d8f08b1e      1
# 4880        4880  c32030a889357e90      1
# 4881        4881  ee59f1ad5679e2fd      1
# 4882        4882  f915a599f00189f8      1
# 4883        4883  7c1473256652e354      1
# 4884        4884  db1e380d7efa416a      1
# 4885        4885  50a9eae6d74fa7c9      1
#
# [4886 rows x 3 columns]

# %%
Pkey= pd.read_csv('keywordID.csv')
KeywordCount=np.empty((len(Pkey),2),dtype='object')
for i in range(len(KeywordCount)):
    KeywordCount[i][1]=0
for i in range(len(Pkey)):
    KeywordCount[i][0]=Pkey['KeywordID'][i]

# %%
for i in range(956,len(Pdata)):
    for j in range(len(KeywordCount)):
        if KeywordCount[j][0]==Pdata['index'][i]:
            KeywordCount[j][1]+=Pdata['K6'][i]
            break

# %%
i
# Out:
# 956

# %%
KeywordCount
# Out:
# array([['100090ebe40971fd', 0],
#        ['1001140e40fff9fd', 0],
#        ['10024382a4ae7a07', 0],
#        ...,
#        ['fffdbb80538ef8ed', 50],
#        ['fffef5deb4bb2e96', 0],
#        ['ffff85b5babbe077', 0]], dtype=object)

# %%
np.savetxt("finish6.csv", KeywordCount ,fmt='%5s',delimiter=",")
