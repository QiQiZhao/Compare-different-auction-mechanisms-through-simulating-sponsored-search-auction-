# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from time import process_time

# %%
Pdata= pd.read_csv('K5.csv')

# %%
Pdata
# Out:
#        Unnamed: 0             index      K4
# 0               0  fc4f04e287746c48  496482
# 1               1  79021a2e2c836c1a  295498
# 2               2  324ac734097de5e4  256583
# 3               3  818c76aa1c8fcfcb  249093
# 4               4  2ac01c3be4bef1a8  105310
# 5               5  62129a60c2c67093   96049
# 6               6  6a82ef5b6ade294f   92424
# 7               7  a4630d2f744bb704   80182
# 8               8  2fb9ae05f5dbf8f4   77835
# 9               9  376b9d520656fcf6   75773
# 10             10  5e4d035e3a82ec8f   68089
# 11             11  2c154d6f92573c8b   67500
# 12             12  a36ccf9abc1281b3   66784
# 13             13  7d49570aacd3c2a5   66360
# 14             14  174fc33c6a0afe1c   61308
# 15             15  5b9834ef1db9cdf7   57957
# 16             16  d777cfa1462b7c50   56544
# 17             17  4fe1e24de9b82425   49076
# 18             18  7634c051426a6995   47620
# 19             19  8b9f17e47e6282fc   45477
# 20             20  4250deb8ef95417a   36382
# 21             21  ad784b7b6433cd6e   34551
# 22             22  a6a0665e425a2fbb   33207
# 23             23  30886045ac687868   32420
# 24             24  b5cff54170800355   31149
# 25             25  8a6e919b5292bbeb   30990
# 26             26  1be1668b5a9df819   30596
# 27             27  210be76195db767d   28733
# 28             28  544aed54f77c886e   28090
# 29             29  7b7b9b0586cad55f   27143
# ...           ...               ...     ...
# 17834       17834  1f7ce54deddf1356       1
# 17835       17835  babfd6d14b58d001       1
# 17836       17836  7d89c3b3bb866e58       1
# 17837       17837  8022ced021dd0a1d       1
# 17838       17838  7df758fabbfa5b6f       1
# 17839       17839  3a8c864305e29ade       1
# 17840       17840  3927a38330af632e       1
# 17841       17841  9286f0d9d86970d7       1
# 17842       17842  bf26909416b3dd06       1
# 17843       17843  540ae307413063d9       1
# 17844       17844  fd17076a4645fab3       1
# 17845       17845  6a149f882828d48d       1
# 17846       17846  b9e2866a7efd495c       1
# 17847       17847  117505c1bcb35cdc       1
# 17848       17848  5e2009b4bfcef8da       1
# 17849       17849  4489719296d9b8a2       1
# 17850       17850  491a0099eb0a7e00       1
# 17851       17851  18670fbfb69fecb0       1
# 17852       17852  336469926e27e31a       1
# 17853       17853  b6678a91fdf57ed9       1
# 17854       17854  dbe6ab1f7aa95225       1
# 17855       17855  ab70026aff104699       1
# 17856       17856  dc92ad1129593292       1
# 17857       17857  eaf577eb714ccc33       1
# 17858       17858  96605e658222cab7       1
# 17859       17859  62a9c6b7873b8aa3       1
# 17860       17860  353c3ea5901307aa       1
# 17861       17861  a5e1ba61a37365c5       1
# 17862       17862  44170fa9c88c06d6       1
# 17863       17863  79f43031eb11b0c7       1
#
# [17864 rows x 3 columns]

# %%
Pkey= pd.read_csv('keywordID.csv')
KeywordCount=np.empty((len(Pkey),2),dtype='object')
for i in range(len(KeywordCount)):
    KeywordCount[i][1]=0
for i in range(len(Pkey)):
    KeywordCount[i][0]=Pkey['KeywordID'][i]

# %%
for i in range(986,len(Pdata)):
    for j in range(len(KeywordCount)):
        if KeywordCount[j][0]==Pdata['index'][i]:
            KeywordCount[j][1]+=Pdata['K5'][i]
            break

# %%
np.savetxt("finish5.csv", KeywordCount ,fmt='%5s',delimiter=",")

# %%
Pdata= pd.read_csv('K4.csv')
